# %%
##DONT FORGET TO ENTER CREDIT SCORE FOR PROJECT/BHIRA/RAVTHUMI/AND SO ON...

gradeDict = {
    "District math 1" : 0,
    "Algebra 1" : 0,
    "Computer Systems" : 0,
    "Computer Science" : 0,
    
    "District math 2" : 0,
    "Infy math 1" : 0,
    "Data Strctures" : 0,
    "Advanced C" : 0,
    "C++" : 0,
    
    "Probability" : 0,
    "Algebra 2" : 0,
    "Infy math 2" : 0,
    "Computer Networks" : 0,
    "Algo 1" : 0,
    
    "OS" : 0,
    "SE" : 0,
    "Data Science" : 0,
    "Data Bases" : 0,
    "Machine Learning" : 0,
    "Algo 2" : 0,
    
    "Automata theory" : 0,
    "Complexity Algo" : 0,
    
    "yezmut" : 0,
    "rav thumi 1" : 0,
    "rav thumi 2" : 0,
    
    "Project 1" : 0,
    "Project 2" : 0,
    
    "Course Bhira 1" : 0,
    "Course Bhira 2" : 0,
    "Course Bhira 3" : 0,
    "Course Bhira 4" : 0,
    "Course Bhira 5" : 0,
    "Course Bhira 6" : 0,
    "Course Bhira 7" : 0,
    "Course Bhira 8" : 0,   
}

##DONT FORGET TO ENTER CREDIT SCORE FOR PROJECT/BHIRA/RAVTHUMI/AND SO ON... 

crditScoreDict = {
    "District math 1" : 4.0,
    "Algebra 1" : 5.0,
    "Computer Systems" : 4.0,
    "Computer Science" : 5.0,
    
    "District math 2" : 3.0,
    "Infy math 1" : 6.5,
    "Data Strctures" : 4.0,
    "Advanced C" : 3.0,
    "C++" : 5.0,
    
    "Probability" : 3.5,
    "Algebra 2" : 4.0,
    "Infy math 2" : 4.0,
    "Computer Networks" : 3.5,
    "Algo 1" : 4.0,
    
    "OS" : 3.5,
    "SE" : 4.0,
    "Data Science" : 3.5,
    "Data Bases" : 4.0,
    "Machine Learning" : 4.0,
    "Algo 2" : 4.0,
    
    "Automata theory" : 4.0,
    "Complexity Algo" : 4.0,
    
    ##READ ME!! 
    ##DONT FORGET TO ENTER CREDIT SCORE FOR PROJECT/BHIRA/RAVTHUMI/AND SO ON... 
    
    "yezmut" : 2.0,
    "rav thumi 1" : 4.0,
    "rav thumi 2" : 0.0,
    
    "Project 1" : 0.0,
    "Project 2" : 0.0,
    
    "Course Bhira 1" : 3.0,
    "Course Bhira 2" : 3.0,
    "Course Bhira 3" : 3.0,
    "Course Bhira 4" : 3.0,
    "Course Bhira 5" : 3.0,
    "Course Bhira 6" : 3.0,
    "Course Bhira 7" : 3.0,
    "Course Bhira 8" : 3.0,   
}

# %%
totalCredits = 0.0
grades = 0.0

for o in gradeDict:
    for i in crditScoreDict:
        if o == i and gradeDict[o] != 0:
            totalCredits += crditScoreDict[o]
            grades += gradeDict[o]*crditScoreDict[o]
            
if totalCredits != 0:        
    print("{:.2f}".format(grades/totalCredits))
else:
    print("You didnt enter anything...")
